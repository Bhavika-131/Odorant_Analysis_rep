# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('OD-CAS-data.csv')

# %%
df.head()
# Out:
#               smiles  OR52W1  OR14J1  OR1G1  OR52J3  OR52I1  OR52H1  OR11H4  \
# 0            CSCCC=O   0.989   0.989  0.987   0.983   0.975   0.975   0.973
# 1          CCC(C)C=O   0.928   0.875  0.980   0.855     NaN   0.873     NaN
# 2       CC(=O)C(C)=O     NaN     NaN    NaN     NaN     NaN     NaN     NaN
# 3  CCCCC/C=C/C=C/C=O   0.979   0.841  0.972   0.945     NaN   0.952     NaN
# 4  CC1OC(=C(O)C1=O)C   0.968     NaN    NaN   0.944     NaN     NaN     NaN
#
#    OR13C5  OR2T2  ...  OR10S1  OR10G3  OR52A1  OR11h6  OR51E2  OR2M4  OR11A1  \
# 0   0.971  0.970  ...     NaN     NaN     NaN     NaN     NaN    NaN     NaN
# 1   0.727  0.691  ...     NaN     NaN     NaN     NaN     NaN    NaN     NaN
# 2     NaN    NaN  ...     NaN     NaN     NaN     NaN     NaN    NaN     NaN
# 3     NaN    NaN  ...     NaN     NaN     NaN     NaN     NaN    NaN     NaN
# 4     NaN  0.938  ...     NaN     NaN     NaN     NaN     NaN    NaN     NaN
#
#    OR1A2  OR2M3  OR13A1
# ...

# %%
df
# Out:
#                         smiles  OR52W1  OR14J1  OR1G1  OR52J3  OR52I1  OR52H1  \
# 0                      CSCCC=O   0.989   0.989  0.987   0.983   0.975   0.975
# 1                    CCC(C)C=O   0.928   0.875  0.980   0.855     NaN   0.873
# 2                 CC(=O)C(C)=O     NaN     NaN    NaN     NaN     NaN     NaN
# 3            CCCCC/C=C/C=C/C=O   0.979   0.841  0.972   0.945     NaN   0.952
# 4            CC1OC(=C(O)C1=O)C   0.968     NaN    NaN   0.944     NaN     NaN
# ..                         ...     ...     ...    ...     ...     ...     ...
# 218                   CCCSSCCC   0.992     NaN  0.980   0.986     NaN   0.964
# 219            CCOC(=O)CCC(C)C   0.993     NaN  0.984   0.989     NaN   0.972
# 220               CCOC(=O)CCSC   0.988   0.960  0.979   0.985     NaN   0.958
# 221  CCCC[C@@H](CC)CCC([O-])=O   0.957   0.996  0.963   0.923   0.986   0.954
# 222    COC1=C(C=C(C=C1)CC=C)OC   0.998   0.995  0.994   0.996     NaN     NaN
#
# ...

# %%
df.dtypes
# Out:
# smiles     object
# OR52W1    float64
# OR14J1    float64
# OR1G1     float64
# OR52J3    float64
#            ...
# OR2M4     float64
# OR11A1    float64
# OR1A2     float64
# OR2M3     float64
# OR13A1    float64
# Length: 80, dtype: object

# %%
sns.heatmap(df.corr())

# %%
# importing pandas as pd
import pandas as pd

# %%
df
# Out:
#                         smiles  OR52W1  OR14J1  OR1G1  OR52J3  OR52I1  OR52H1  \
# 0                      CSCCC=O   0.989   0.989  0.987   0.983   0.975   0.975
# 1                    CCC(C)C=O   0.928   0.875  0.980   0.855     NaN   0.873
# 2                 CC(=O)C(C)=O     NaN     NaN    NaN     NaN     NaN     NaN
# 3            CCCCC/C=C/C=C/C=O   0.979   0.841  0.972   0.945     NaN   0.952
# 4            CC1OC(=C(O)C1=O)C   0.968     NaN    NaN   0.944     NaN     NaN
# ..                         ...     ...     ...    ...     ...     ...     ...
# 218                   CCCSSCCC   0.992     NaN  0.980   0.986     NaN   0.964
# 219            CCOC(=O)CCC(C)C   0.993     NaN  0.984   0.989     NaN   0.972
# 220               CCOC(=O)CCSC   0.988   0.960  0.979   0.985     NaN   0.958
# 221  CCCC[C@@H](CC)CCC([O-])=O   0.957   0.996  0.963   0.923   0.986   0.954
# 222    COC1=C(C=C(C=C1)CC=C)OC   0.998   0.995  0.994   0.996     NaN     NaN
#
# ...

# %%
cols = ['OR52W1', 'OR13A1']

df[cols].mean()
# Out:
# OR52W1    0.952531
# OR13A1    0.958000
# dtype: float64

# %%
#finding the mean of each of the 76 ORs 
df.mean(axis = 0)
# Out:
# C:\Users\Dell\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# OR52W1    0.952531
# OR14J1    0.913654
# OR1G1     0.929995
# OR52J3    0.939649
# OR52I1    0.857783
#             ...
# OR2M4     0.804000
# OR11A1    0.701500
# OR1A2     0.862500
# OR2M3     0.645000
# OR13A1    0.958000
# Length: 76, dtype: float64

# %%
# Calculate mean of each of the 76 ORs
val = df.mean()
print(val)
# Out:
# OR52W1    0.952531
# OR14J1    0.913654
# OR1G1     0.929995
# OR52J3    0.939649
# OR52I1    0.857783
#             ...
# OR2M4     0.804000
# OR11A1    0.701500
# OR1A2     0.862500
# OR2M3     0.645000
# OR13A1    0.958000
# Length: 76, dtype: float64
# C:\Users\Dell\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.

# %%
# top n ORs ordered by multiple columns
val.nlargest(10)
# Out:
# OR2J1       0.962434
# OR10A4      0.961667
# OR13A1      0.958000
# OR8H3       0.955950
# OR4Q3       0.954917
# OR52W1      0.952531
# OR10G6      0.952184
# OR2A25      0.951000
# OR2B11      0.948500
# OR52J3.1    0.945000
# dtype: float64

# %%
# Using DataFrame.sum() to Sum each row of OR
df2 = df.iloc[:,1:78].sum()
print(df2)
# Out:
# OR52W1    182.886
# OR14J1     74.006
# OR1G1     172.049
# OR52J3    173.835
# OR52I1     19.729
#            ...
# OR11h6      4.829
# OR51E2      1.372
# OR2M4       0.804
# OR11A1      1.403
# OR1A2       1.725
# Length: 74, dtype: float64
# C:\Users\Dell\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.

# %%
# top n rows ordered by multiple columns
df2.nlargest(10)
# Out:
# OR52W1    182.886
# OR52J3    173.835
# OR1G1     172.049
# OR2T2     145.332
# OR52H1    120.424
# OR4E2     111.818
# OR8H2      84.736
# OR2J1      79.882
# OR14J1     74.006
# OR5AN1     60.142
# dtype: float64

# %%
df0 = df.mean(axis=1)
print(df0)
# Out:
# 0      0.978100
# 1      0.778500
# 2      0.857300
# 3      0.881091
# 4      0.956000
#          ...
# 218    0.973800
# 219    0.973400
# 220    0.964400
# 221    0.972600
# 222    0.996111
# Length: 223, dtype: float64
# C:\Users\Dell\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.

# %%
# top n rows ordered by multiple columns
df0.nlargest(10)
# Out:
# 12     0.998000
# 187    0.997700
# 39     0.997000
# 222    0.996111
# 164    0.995900
# 56     0.995444
# 82     0.995444
# 96     0.993333
# 131    0.990100
# 100    0.988100
# dtype: float64

# %%
# Average of each column using DataFrame.mean()
df2 = df.sum(axis=1)
print(df2)
# Out:
# 0      9.781
# 1      7.785
# 2      8.573
# 3      9.692
# 4      8.604
#        ...
# 218    9.738
# 219    9.734
# 220    9.644
# 221    9.726
# 222    8.965
# Length: 223, dtype: float64
# C:\Users\Dell\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.

# %%
# top n rows ordered by multiple columns
dataframe= df2.nlargest(10)
dataframe
# Out:
# 29     11.500
# 138    11.339
# 183    11.325
# 142    10.807
# 194    10.639
# 172    10.259
# 60     10.141
# 12      9.980
# 187     9.977
# 164     9.959
# dtype: float64

# %%
d_29=df.iloc[164,0]
d_29
# Out:
# 'COC1=C(C=C(C=C1)CC=C)OC'

# %%
dataframe.smiles
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13784\2877815582.py in <module>
# ----> 1 dataframe.smiles
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'smiles'
